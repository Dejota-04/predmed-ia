# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_absolute_error
import pickle

# %%
# Carregar os dados (substitua o caminho com o dataset do trem)
df = pd.read_csv('C:/Users/labsfiap/Documents/CCR/dados.csv', encoding='ISO-8859-1', sep=';')
df
# Out:
#      # Horário  TMP (min) Dia da Semana  Lotação (%)  Atraso (min)  \
# 0    0   05:00       12.0       Domingo         30.0           1.0
# 1    1   06:30       14.0       Domingo         45.0           2.0
# 2    2   08:00       20.0       Domingo         85.0           6.0
# 3    3   09:15       18.0       Domingo         75.0           4.0
# 4    4   10:45       13.0       Domingo         60.0           3.0
# ..  ..     ...        ...           ...          ...           ...
# 84  84   19:30       16.0         Terça         74.0           4.0
# 85  85   21:00       14.5         Terça         62.0           2.0
# 86  86   22:30       13.0         Terça         51.0           1.0
# 87  87   23:59       11.0         Terça         39.0           0.0
# 88  88   01:00       10.0         Terça         30.0           0.0
#
#               Estação Tipo de Trem
# 0         Barra Funda         Novo
# 1       Júlio Prestes       Antigo
# 2              Osasco         Novo
# 3   Presidente Altino       Antigo
# 4             Barueri         Novo
# ..                ...          ...
# 84        Barra Funda         Novo
# 85      Júlio Prestes       Antigo
# 86             Osasco         Novo
# 87  Presidente Altino       Antigo
# 88            Barueri         Novo
#
# [89 rows x 8 columns]

# %%
# Converte "HH:MM" para minutos
def horario_para_minutos(hora):
    h, m = map(int, hora.split(":"))
    return h * 60 + m

df["Horário_min"] = df["Horário"].apply(horario_para_minutos)

# Seleção de features e target
X = df[["Horário_min", "Dia da Semana", "Lotação (%)", "Atraso (min)"]]
y = df["TMP (min)"]

# %%
# ======================
# 3. Dividir dados
# ======================

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# ======================
# 4. Pipeline + Modelo
# ======================

cat_features = ["Dia da Semana"]
num_features = ["Horário_min", "Lotação (%)", "Atraso (min)"]

preprocessor = ColumnTransformer([
    ("cat", OneHotEncoder(handle_unknown="ignore"), cat_features),
    ("num", "passthrough", num_features)
])

# %%
# MLP Regressor com estrutura semelhante ao MNIST
pipeline = Pipeline([
    ("preprocessor", preprocessor),
    ("regressor", MLPRegressor(hidden_layer_sizes=(50, 20), max_iter=1000, random_state=42, verbose=True))
])

pipeline.fit(X_train, y_train)
# Out:
# Iteration 1, loss = 478.63986955
# Iteration 2, loss = 204.19361136
# Iteration 3, loss = 131.82183514
# Iteration 4, loss = 167.85537776
# Iteration 5, loss = 202.26506380
# Iteration 6, loss = 196.38327557
# Iteration 7, loss = 161.74085896
# Iteration 8, loss = 121.06721321
# Iteration 9, loss = 93.22592635
# Iteration 10, loss = 85.68564804
# Iteration 11, loss = 95.40548727
# Iteration 12, loss = 111.17956773
# Iteration 13, loss = 121.07795704
# Iteration 14, loss = 119.29682628
# Iteration 15, loss = 107.45108017
# Iteration 16, loss = 91.80948293
# Iteration 17, loss = 79.13120598
# Iteration 18, loss = 73.51063164
# Iteration 19, loss = 74.99136114
# Iteration 20, loss = 80.19353086
# Iteration 21, loss = 84.43834417
# Iteration 22, loss = 84.40890014
# Iteration 23, loss = 79.60538490
# Iteration 24, loss = 72.04989520
# Iteration 25, loss = 64.79222827
# Iteration 26, loss = 60.25151387
# Iteration 27, loss = 59.06547002
# Iteration 28, loss = 60.04048392
# Iteration 29, loss = 61.01643201
# Iteration 30, loss = 60.13351958
# Iteration 31, loss = 56.97118364
# Iteration 32, loss = 52.43221643
# Iteration 33, loss = 48.11828448
# Iteration 34, loss = 45.28795123
# Iteration 35, loss = 44.16837834
# Iteration 36, loss = 44.03870165
# Iteration 37, loss = 43.70891862
# Iteration 38, loss = 42.33038064
# Iteration 39, loss = 39.92126436
# Iteration 40, loss = 37.05943851
# Iteration 41, loss = 34.54854510
# Iteration 42, loss = 32.96592573
# Iteration 43, loss = 32.27766499
# Iteration 44, loss = 31.90651179
# Iteration 45, loss = 31.25796219
# Iteration 46, loss = 30.10248820
# Iteration 47, loss = 28.60371225
# Iteration 48, loss = 27.18282929
# Iteration 49, loss = 26.15993412
# Iteration 50, loss = 25.53854841
# Iteration 51, loss = 24.63845757
# Iteration 52, loss = 22.96150368
# Iteration 53, loss = 20.42022534
# Iteration 54, loss = 17.60772904
# Iteration 55, loss = 14.75151636
# Iteration 56, loss = 12.61973045
# Iteration 57, loss = 12.20608065
# Iteration 58, loss = 11.48436807
# Iteration 59, loss = 10.64722268
# Iteration 60, loss = 10.08195565
# Iteration 61, loss = 9.66055659
# Iteration 62, loss = 9.05389370
# Iteration 63, loss = 8.32727857
# Iteration 64, loss = 7.77816721
# Iteration 65, loss = 7.30564170
# Iteration 66, loss = 6.67491378
# Iteration 67, loss = 5.99660549
# Iteration 68, loss = 5.47057618
# Iteration 69, loss = 4.95709413
# Iteration 70, loss = 4.26733458
# Iteration 71, loss = 3.56652365
# Iteration 72, loss = 2.98780796
# Iteration 73, loss = 2.46820940
# Iteration 74, loss = 1.94923021
# Iteration 75, loss = 1.55173873
# Iteration 76, loss = 1.29766514
# Iteration 77, loss = 1.09489476
# Iteration 78, loss = 0.97015821
# Iteration 79, loss = 1.03465588
# Iteration 80, loss = 1.11340790
# Iteration 81, loss = 1.16914840
# Iteration 82, loss = 1.32625020
# Iteration 83, loss = 1.45155643
# Iteration 84, loss = 1.47317951
# Iteration 85, loss = 1.50739349
# Iteration 86, loss = 1.51857739
# Iteration 87, loss = 1.44201432
# Iteration 88, loss = 1.36674141
# Iteration 89, loss = 1.30374083
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Dia da Semana']),
#                                                  ('num', 'passthrough',
#                                                   ['Horário_min', 'Lotação (%)',
#                                                    'Atraso (min)'])])),
#                 ('regressor',
#                  MLPRegressor(hidden_layer_sizes=(50, 20), max_iter=1000,
#                               random_state=42, verbose=True))])

# %%
# ======================
# 5. Avaliação
# ======================

y_pred = pipeline.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
print(f"MAE: {mae:.2f} minutos")
# Out:
# MAE: 1.24 minutos

# %%
# ======================
# 6. Salvar modelo
# ======================

with open("mlp_previsao_trem.pkl", "wb") as f:
    pickle.dump(pipeline, f)
